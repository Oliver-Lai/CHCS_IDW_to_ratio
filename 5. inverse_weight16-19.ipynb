# %% [markdown]
# ### 將離散站點以反距離權重法計算出擴散圖

# %%
import os
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.font_manager as fm
from matplotlib.cm import ScalarMappable

from matplotlib import colors
from descartes import PolygonPatch
from matplotlib.patches import PathPatch
from matplotlib.path import Path

# 設定中文字體
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei', 'SimHei', 'Microsoft YaHei', 'STHeiti']
plt.rcParams['axes.unicode_minus'] = False

# %%
from shapely.geometry import shape, Polygon, MultiPolygon
from shapely import wkt
import math
import aqi_helper as helper

# %% [markdown]
# ### 以已知網格點計算未知網格點值

# %%
def calc_idw_value(unknowncell, knowncells):
    sumwei = 0.0
    sumpm = 0.0
    wei = 0.0
    for index, row in knowncells.iterrows():
        px = unknowncell['x']
        py = unknowncell['y']
        pm = row['value']
        diss = math.sqrt(math.pow((px - row['lng']), 2) + math.pow((py - row['lat']), 2))
        dis = diss * 345
        if dis < 300:
            if dis < 1:
                dis = 1
            wei = 1 / math.pow(dis, 3)
            sumpm += pm * wei
            sumwei += wei
    if sumwei > 0:
        return round(sumpm / sumwei)
    else:
        return -1

# %% [markdown]
# ### 生成台灣範圍的空網格後，將離散測站點的資料丟給上面的calc_idw_value()計算網格值

# %%
def calculate_idw(data): #計算網格IDW數值
    df = data #將測站site、lng、lat、value，DataFrame輸入

    # 將非數值轉為 NaN 並排除（這一步是關鍵）
    df['value'] = pd.to_numeric(df['value'], errors='coerce')
    df = df.dropna(subset=['value'])  # <--- 只用有數值的測站進行插值

    if df.empty:
        return np.full((120, 120), -1)  # 全部無資料時直接回傳 -1 網格
    
    df['value'].astype(float)#將value欄位轉成數值型態
    gdf = gpd.GeoDataFrame(
        df, geometry=gpd.points_from_xy(df.lng, df.lat))
    gdf.crs = 'EPSG:3826'
    gdf['geometry'] = gdf.geometry.buffer(0.015)

    iInterval = (122.7 - 119) / 120
    jInterval = (25.5 - 21.8) / 120
    result = []
    index1 = 0
    index2 = 0
    for j in np.arange(25.5, 21.8, -jInterval):
        nested = []
        for i in np.arange(119, 122.7, iInterval):
            point = {'x': i, 'y': j}
            if helper.is_in_area(index1, index2):
                nested.append(calc_idw_value(point, df))
            else:
                nested.append(-1)
            index2 += 1
        result.append(nested)
        index1 += 1
        index2 = 0

    result = np.array(result)

    return result

# %% [markdown]
# ### 讀取台灣地圖gml檔與測站座標檔，接著進行IDW插值主函式

# %%
# --- 地圖與測站座標 ---
taiwan_map = gpd.read_file('./TOWN_MOI_1131028.gml')

site = pd.read_csv('./Preview_Data.csv')[['sitename','twd97lon','twd97lat']]
site.columns = ['site','lng','lat']
excluded_sites = ['富貴角', '馬祖', '金門', '馬公']
site = site[~site['site'].isin(excluded_sites)]

# --- 插值主函數 ---
def interpolate_by_idw(factor, input_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)

    for year in range(2015, 2020):
        input_path = os.path.join(input_dir, factor, f"{factor}_merged_{year}.csv")
        if not os.path.exists(input_path):
            print(f"❌ 檔案不存在: {input_path}")
            continue

        df = pd.read_csv(input_path)
        if '日期' not in df.columns:
            print(f"⚠️ 檔案格式錯誤（缺少日期）: {input_path}")
            continue

        df = df.set_index('日期')
        print(f"📂 處理 {factor} - {year}，共 {len(df)} 筆日期")

        m2 = []
        for count, date_str in enumerate(df.index):
            df_row = pd.DataFrame(df.iloc[count]).reset_index()
            df_row.columns = ['site', 'value']

            # 合併座標資料
            df_merge = pd.merge(site, df_row, on='site', how='inner')

            if df_merge['value'].isna().all():
                print(f"⚠️ {date_str} 無任何資料，跳過")
                m2.append(np.full((120, 120), np.nan))
                continue

            grid = calculate_idw(df_merge)
            m2.append(grid)
            print(f"{year} 年 {factor} 第 {count+1}/{len(df)} 筆完成")

        m2_array = np.round(np.array(m2), 2)

        # 儲存每筆（每週或每月）為獨立 CSV
        for index, grid in enumerate(m2_array, start=1):
            output_file = os.path.join(output_dir, f"{factor}_{year}_week_{index}.csv")
            pd.DataFrame(grid).to_csv(output_file, index=False)
            print(f"✅ 輸出：{output_file}")

# --- 執行程式 ---
if __name__ == "__main__":
    factors = ["NO", "NO2", "NOx", "O3", "PM10", "PM2.5", "SO2", "AMB_TEMP", "RH"]
    input_dir = './4_interpolated_yearly_stationwise'
    output_base = './5_grid_output'

    for factor in factors:
        factor_folder = os.path.join(output_base, factor.replace('.', ''))  # PM2.5 → PM25
        interpolate_by_idw(factor.replace('.', ''), input_dir, factor_folder)
# Out:
# 📂 處理 NO - 2015，共 52 筆日期
# 2015 年 NO 第 1/52 筆完成
# 2015 年 NO 第 2/52 筆完成
# 2015 年 NO 第 3/52 筆完成
# 2015 年 NO 第 4/52 筆完成
# 2015 年 NO 第 5/52 筆完成
# 2015 年 NO 第 6/52 筆完成
# 2015 年 NO 第 7/52 筆完成
# 2015 年 NO 第 8/52 筆完成
# 2015 年 NO 第 9/52 筆完成
# 2015 年 NO 第 10/52 筆完成
# 2015 年 NO 第 11/52 筆完成
# 2015 年 NO 第 12/52 筆完成
# 2015 年 NO 第 13/52 筆完成
# 2015 年 NO 第 14/52 筆完成
# 2015 年 NO 第 15/52 筆完成
# 2015 年 NO 第 16/52 筆完成
# 2015 年 NO 第 17/52 筆完成
# 2015 年 NO 第 18/52 筆完成
# 2015 年 NO 第 19/52 筆完成
# 2015 年 NO 第 20/52 筆完成
# 2015 年 NO 第 21/52 筆完成
# 2015 年 NO 第 22/52 筆完成
# 2015 年 NO 第 23/52 筆完成
# 2015 年 NO 第 24/52 筆完成
# 2015 年 NO 第 25/52 筆完成
# 2015 年 NO 第 26/52 筆完成
# 2015 年 NO 第 27/52 筆完成
# 2015 年 NO 第 28/52 筆完成
# 2015 年 NO 第 29/52 筆完成
# 2015 年 NO 第 30/52 筆完成
# 2015 年 NO 第 31/52 筆完成
# 2015 年 NO 第 32/52 筆完成
# 2015 年 NO 第 33/52 筆完成
# 2015 年 NO 第 34/52 筆完成
# 2015 年 NO 第 35/52 筆完成
# 2015 年 NO 第 36/52 筆完成
# 2015 年 NO 第 37/52 筆完成
# 2015 年 NO 第 38/52 筆完成
# 2015 年 NO 第 39/52 筆完成
# 2015 年 NO 第 40/52 筆完成
# 2015 年 NO 第 41/52 筆完成
# 2015 年 NO 第 42/52 筆完成
# 2015 年 NO 第 43/52 筆完成
# 2015 年 NO 第 44/52 筆完成
# 2015 年 NO 第 45/52 筆完成
# 2015 年 NO 第 46/52 筆完成
# 2015 年 NO 第 47/52 筆完成
# 2015 年 NO 第 48/52 筆完成
# 2015 年 NO 第 49/52 筆完成
# 2015 年 NO 第 50/52 筆完成
# 2015 年 NO 第 51/52 筆完成
# 2015 年 NO 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_1.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_2.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_3.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_4.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_5.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_6.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_7.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_8.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_9.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_10.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_11.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_12.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_13.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_14.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_15.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_16.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_17.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_18.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_19.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_20.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_21.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_22.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_23.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_24.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_25.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_26.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_27.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_28.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_29.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_30.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_31.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_32.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_33.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_34.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_35.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_36.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_37.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_38.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_39.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_40.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_41.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_42.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_43.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_44.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_45.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_46.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_47.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_48.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_49.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_50.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_51.csv
# ✅ 輸出：./5_grid_output/NO/NO_2015_week_52.csv
# 📂 處理 NO - 2016，共 52 筆日期
# 2016 年 NO 第 1/52 筆完成
# 2016 年 NO 第 2/52 筆完成
# 2016 年 NO 第 3/52 筆完成
# 2016 年 NO 第 4/52 筆完成
# 2016 年 NO 第 5/52 筆完成
# 2016 年 NO 第 6/52 筆完成
# 2016 年 NO 第 7/52 筆完成
# 2016 年 NO 第 8/52 筆完成
# 2016 年 NO 第 9/52 筆完成
# 2016 年 NO 第 10/52 筆完成
# 2016 年 NO 第 11/52 筆完成
# 2016 年 NO 第 12/52 筆完成
# 2016 年 NO 第 13/52 筆完成
# 2016 年 NO 第 14/52 筆完成
# 2016 年 NO 第 15/52 筆完成
# 2016 年 NO 第 16/52 筆完成
# 2016 年 NO 第 17/52 筆完成
# 2016 年 NO 第 18/52 筆完成
# 2016 年 NO 第 19/52 筆完成
# 2016 年 NO 第 20/52 筆完成
# 2016 年 NO 第 21/52 筆完成
# 2016 年 NO 第 22/52 筆完成
# 2016 年 NO 第 23/52 筆完成
# 2016 年 NO 第 24/52 筆完成
# 2016 年 NO 第 25/52 筆完成
# 2016 年 NO 第 26/52 筆完成
# 2016 年 NO 第 27/52 筆完成
# 2016 年 NO 第 28/52 筆完成
# 2016 年 NO 第 29/52 筆完成
# 2016 年 NO 第 30/52 筆完成
# 2016 年 NO 第 31/52 筆完成
# 2016 年 NO 第 32/52 筆完成
# 2016 年 NO 第 33/52 筆完成
# 2016 年 NO 第 34/52 筆完成
# 2016 年 NO 第 35/52 筆完成
# 2016 年 NO 第 36/52 筆完成
# 2016 年 NO 第 37/52 筆完成
# 2016 年 NO 第 38/52 筆完成
# 2016 年 NO 第 39/52 筆完成
# 2016 年 NO 第 40/52 筆完成
# 2016 年 NO 第 41/52 筆完成
# 2016 年 NO 第 42/52 筆完成
# 2016 年 NO 第 43/52 筆完成
# 2016 年 NO 第 44/52 筆完成
# 2016 年 NO 第 45/52 筆完成
# 2016 年 NO 第 46/52 筆完成
# 2016 年 NO 第 47/52 筆完成
# 2016 年 NO 第 48/52 筆完成
# 2016 年 NO 第 49/52 筆完成
# 2016 年 NO 第 50/52 筆完成
# 2016 年 NO 第 51/52 筆完成
# 2016 年 NO 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_1.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_2.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_3.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_4.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_5.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_6.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_7.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_8.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_9.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_10.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_11.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_12.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_13.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_14.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_15.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_16.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_17.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_18.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_19.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_20.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_21.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_22.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_23.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_24.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_25.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_26.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_27.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_28.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_29.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_30.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_31.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_32.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_33.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_34.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_35.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_36.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_37.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_38.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_39.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_40.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_41.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_42.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_43.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_44.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_45.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_46.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_47.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_48.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_49.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_50.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_51.csv
# ✅ 輸出：./5_grid_output/NO/NO_2016_week_52.csv
# 📂 處理 NO - 2017，共 52 筆日期
# 2017 年 NO 第 1/52 筆完成
# 2017 年 NO 第 2/52 筆完成
# 2017 年 NO 第 3/52 筆完成
# 2017 年 NO 第 4/52 筆完成
# 2017 年 NO 第 5/52 筆完成
# 2017 年 NO 第 6/52 筆完成
# 2017 年 NO 第 7/52 筆完成
# 2017 年 NO 第 8/52 筆完成
# 2017 年 NO 第 9/52 筆完成
# 2017 年 NO 第 10/52 筆完成
# 2017 年 NO 第 11/52 筆完成
# 2017 年 NO 第 12/52 筆完成
# 2017 年 NO 第 13/52 筆完成
# 2017 年 NO 第 14/52 筆完成
# 2017 年 NO 第 15/52 筆完成
# 2017 年 NO 第 16/52 筆完成
# 2017 年 NO 第 17/52 筆完成
# 2017 年 NO 第 18/52 筆完成
# 2017 年 NO 第 19/52 筆完成
# 2017 年 NO 第 20/52 筆完成
# 2017 年 NO 第 21/52 筆完成
# 2017 年 NO 第 22/52 筆完成
# 2017 年 NO 第 23/52 筆完成
# 2017 年 NO 第 24/52 筆完成
# 2017 年 NO 第 25/52 筆完成
# 2017 年 NO 第 26/52 筆完成
# 2017 年 NO 第 27/52 筆完成
# 2017 年 NO 第 28/52 筆完成
# 2017 年 NO 第 29/52 筆完成
# 2017 年 NO 第 30/52 筆完成
# 2017 年 NO 第 31/52 筆完成
# 2017 年 NO 第 32/52 筆完成
# 2017 年 NO 第 33/52 筆完成
# 2017 年 NO 第 34/52 筆完成
# 2017 年 NO 第 35/52 筆完成
# 2017 年 NO 第 36/52 筆完成
# 2017 年 NO 第 37/52 筆完成
# 2017 年 NO 第 38/52 筆完成
# 2017 年 NO 第 39/52 筆完成
# 2017 年 NO 第 40/52 筆完成
# 2017 年 NO 第 41/52 筆完成
# 2017 年 NO 第 42/52 筆完成
# 2017 年 NO 第 43/52 筆完成
# 2017 年 NO 第 44/52 筆完成
# 2017 年 NO 第 45/52 筆完成
# 2017 年 NO 第 46/52 筆完成
# 2017 年 NO 第 47/52 筆完成
# 2017 年 NO 第 48/52 筆完成
# 2017 年 NO 第 49/52 筆完成
# 2017 年 NO 第 50/52 筆完成
# 2017 年 NO 第 51/52 筆完成
# 2017 年 NO 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_1.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_2.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_3.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_4.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_5.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_6.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_7.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_8.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_9.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_10.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_11.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_12.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_13.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_14.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_15.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_16.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_17.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_18.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_19.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_20.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_21.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_22.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_23.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_24.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_25.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_26.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_27.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_28.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_29.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_30.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_31.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_32.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_33.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_34.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_35.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_36.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_37.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_38.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_39.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_40.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_41.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_42.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_43.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_44.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_45.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_46.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_47.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_48.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_49.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_50.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_51.csv
# ✅ 輸出：./5_grid_output/NO/NO_2017_week_52.csv
# 📂 處理 NO - 2018，共 52 筆日期
# 2018 年 NO 第 1/52 筆完成
# 2018 年 NO 第 2/52 筆完成
# 2018 年 NO 第 3/52 筆完成
# 2018 年 NO 第 4/52 筆完成
# 2018 年 NO 第 5/52 筆完成
# 2018 年 NO 第 6/52 筆完成
# 2018 年 NO 第 7/52 筆完成
# 2018 年 NO 第 8/52 筆完成
# 2018 年 NO 第 9/52 筆完成
# 2018 年 NO 第 10/52 筆完成
# 2018 年 NO 第 11/52 筆完成
# 2018 年 NO 第 12/52 筆完成
# 2018 年 NO 第 13/52 筆完成
# 2018 年 NO 第 14/52 筆完成
# 2018 年 NO 第 15/52 筆完成
# 2018 年 NO 第 16/52 筆完成
# 2018 年 NO 第 17/52 筆完成
# 2018 年 NO 第 18/52 筆完成
# 2018 年 NO 第 19/52 筆完成
# 2018 年 NO 第 20/52 筆完成
# 2018 年 NO 第 21/52 筆完成
# 2018 年 NO 第 22/52 筆完成
# 2018 年 NO 第 23/52 筆完成
# 2018 年 NO 第 24/52 筆完成
# 2018 年 NO 第 25/52 筆完成
# 2018 年 NO 第 26/52 筆完成
# 2018 年 NO 第 27/52 筆完成
# 2018 年 NO 第 28/52 筆完成
# 2018 年 NO 第 29/52 筆完成
# 2018 年 NO 第 30/52 筆完成
# 2018 年 NO 第 31/52 筆完成
# 2018 年 NO 第 32/52 筆完成
# 2018 年 NO 第 33/52 筆完成
# 2018 年 NO 第 34/52 筆完成
# 2018 年 NO 第 35/52 筆完成
# 2018 年 NO 第 36/52 筆完成
# 2018 年 NO 第 37/52 筆完成
# 2018 年 NO 第 38/52 筆完成
# 2018 年 NO 第 39/52 筆完成
# 2018 年 NO 第 40/52 筆完成
# 2018 年 NO 第 41/52 筆完成
# 2018 年 NO 第 42/52 筆完成
# 2018 年 NO 第 43/52 筆完成
# 2018 年 NO 第 44/52 筆完成
# 2018 年 NO 第 45/52 筆完成
# 2018 年 NO 第 46/52 筆完成
# 2018 年 NO 第 47/52 筆完成
# 2018 年 NO 第 48/52 筆完成
# 2018 年 NO 第 49/52 筆完成
# 2018 年 NO 第 50/52 筆完成
# 2018 年 NO 第 51/52 筆完成
# 2018 年 NO 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_1.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_2.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_3.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_4.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_5.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_6.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_7.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_8.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_9.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_10.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_11.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_12.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_13.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_14.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_15.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_16.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_17.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_18.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_19.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_20.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_21.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_22.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_23.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_24.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_25.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_26.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_27.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_28.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_29.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_30.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_31.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_32.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_33.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_34.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_35.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_36.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_37.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_38.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_39.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_40.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_41.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_42.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_43.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_44.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_45.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_46.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_47.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_48.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_49.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_50.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_51.csv
# ✅ 輸出：./5_grid_output/NO/NO_2018_week_52.csv
# 📂 處理 NO - 2019，共 52 筆日期
# 2019 年 NO 第 1/52 筆完成
# 2019 年 NO 第 2/52 筆完成
# 2019 年 NO 第 3/52 筆完成
# 2019 年 NO 第 4/52 筆完成
# 2019 年 NO 第 5/52 筆完成
# 2019 年 NO 第 6/52 筆完成
# 2019 年 NO 第 7/52 筆完成
# 2019 年 NO 第 8/52 筆完成
# 2019 年 NO 第 9/52 筆完成
# 2019 年 NO 第 10/52 筆完成
# 2019 年 NO 第 11/52 筆完成
# 2019 年 NO 第 12/52 筆完成
# 2019 年 NO 第 13/52 筆完成
# 2019 年 NO 第 14/52 筆完成
# 2019 年 NO 第 15/52 筆完成
# 2019 年 NO 第 16/52 筆完成
# 2019 年 NO 第 17/52 筆完成
# 2019 年 NO 第 18/52 筆完成
# 2019 年 NO 第 19/52 筆完成
# 2019 年 NO 第 20/52 筆完成
# 2019 年 NO 第 21/52 筆完成
# 2019 年 NO 第 22/52 筆完成
# 2019 年 NO 第 23/52 筆完成
# 2019 年 NO 第 24/52 筆完成
# 2019 年 NO 第 25/52 筆完成
# 2019 年 NO 第 26/52 筆完成
# 2019 年 NO 第 27/52 筆完成
# 2019 年 NO 第 28/52 筆完成
# 2019 年 NO 第 29/52 筆完成
# 2019 年 NO 第 30/52 筆完成
# 2019 年 NO 第 31/52 筆完成
# 2019 年 NO 第 32/52 筆完成
# 2019 年 NO 第 33/52 筆完成
# 2019 年 NO 第 34/52 筆完成
# 2019 年 NO 第 35/52 筆完成
# 2019 年 NO 第 36/52 筆完成
# 2019 年 NO 第 37/52 筆完成
# 2019 年 NO 第 38/52 筆完成
# 2019 年 NO 第 39/52 筆完成
# 2019 年 NO 第 40/52 筆完成
# 2019 年 NO 第 41/52 筆完成
# 2019 年 NO 第 42/52 筆完成
# 2019 年 NO 第 43/52 筆完成
# 2019 年 NO 第 44/52 筆完成
# 2019 年 NO 第 45/52 筆完成
# 2019 年 NO 第 46/52 筆完成
# 2019 年 NO 第 47/52 筆完成
# 2019 年 NO 第 48/52 筆完成
# 2019 年 NO 第 49/52 筆完成
# 2019 年 NO 第 50/52 筆完成
# 2019 年 NO 第 51/52 筆完成
# 2019 年 NO 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_1.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_2.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_3.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_4.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_5.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_6.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_7.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_8.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_9.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_10.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_11.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_12.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_13.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_14.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_15.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_16.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_17.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_18.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_19.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_20.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_21.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_22.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_23.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_24.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_25.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_26.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_27.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_28.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_29.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_30.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_31.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_32.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_33.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_34.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_35.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_36.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_37.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_38.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_39.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_40.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_41.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_42.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_43.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_44.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_45.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_46.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_47.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_48.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_49.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_50.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_51.csv
# ✅ 輸出：./5_grid_output/NO/NO_2019_week_52.csv
# 📂 處理 NO2 - 2015，共 52 筆日期
# 2015 年 NO2 第 1/52 筆完成
# 2015 年 NO2 第 2/52 筆完成
# 2015 年 NO2 第 3/52 筆完成
# 2015 年 NO2 第 4/52 筆完成
# 2015 年 NO2 第 5/52 筆完成
# 2015 年 NO2 第 6/52 筆完成
# 2015 年 NO2 第 7/52 筆完成
# 2015 年 NO2 第 8/52 筆完成
# 2015 年 NO2 第 9/52 筆完成
# 2015 年 NO2 第 10/52 筆完成
# 2015 年 NO2 第 11/52 筆完成
# 2015 年 NO2 第 12/52 筆完成
# 2015 年 NO2 第 13/52 筆完成
# 2015 年 NO2 第 14/52 筆完成
# 2015 年 NO2 第 15/52 筆完成
# 2015 年 NO2 第 16/52 筆完成
# 2015 年 NO2 第 17/52 筆完成
# 2015 年 NO2 第 18/52 筆完成
# 2015 年 NO2 第 19/52 筆完成
# 2015 年 NO2 第 20/52 筆完成
# 2015 年 NO2 第 21/52 筆完成
# 2015 年 NO2 第 22/52 筆完成
# 2015 年 NO2 第 23/52 筆完成
# 2015 年 NO2 第 24/52 筆完成
# 2015 年 NO2 第 25/52 筆完成
# 2015 年 NO2 第 26/52 筆完成
# 2015 年 NO2 第 27/52 筆完成
# 2015 年 NO2 第 28/52 筆完成
# 2015 年 NO2 第 29/52 筆完成
# 2015 年 NO2 第 30/52 筆完成
# 2015 年 NO2 第 31/52 筆完成
# 2015 年 NO2 第 32/52 筆完成
# 2015 年 NO2 第 33/52 筆完成
# 2015 年 NO2 第 34/52 筆完成
# 2015 年 NO2 第 35/52 筆完成
# 2015 年 NO2 第 36/52 筆完成
# 2015 年 NO2 第 37/52 筆完成
# 2015 年 NO2 第 38/52 筆完成
# 2015 年 NO2 第 39/52 筆完成
# 2015 年 NO2 第 40/52 筆完成
# 2015 年 NO2 第 41/52 筆完成
# 2015 年 NO2 第 42/52 筆完成
# 2015 年 NO2 第 43/52 筆完成
# 2015 年 NO2 第 44/52 筆完成
# 2015 年 NO2 第 45/52 筆完成
# 2015 年 NO2 第 46/52 筆完成
# 2015 年 NO2 第 47/52 筆完成
# 2015 年 NO2 第 48/52 筆完成
# 2015 年 NO2 第 49/52 筆完成
# 2015 年 NO2 第 50/52 筆完成
# 2015 年 NO2 第 51/52 筆完成
# 2015 年 NO2 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_1.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_2.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_3.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_4.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_5.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_6.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_7.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_8.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_9.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_10.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_11.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_12.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_13.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_14.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_15.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_16.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_17.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_18.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_19.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_20.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_21.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_22.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_23.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_24.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_25.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_26.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_27.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_28.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_29.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_30.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_31.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_32.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_33.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_34.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_35.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_36.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_37.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_38.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_39.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_40.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_41.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_42.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_43.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_44.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_45.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_46.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_47.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_48.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_49.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_50.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_51.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2015_week_52.csv
# 📂 處理 NO2 - 2016，共 52 筆日期
# 2016 年 NO2 第 1/52 筆完成
# 2016 年 NO2 第 2/52 筆完成
# 2016 年 NO2 第 3/52 筆完成
# 2016 年 NO2 第 4/52 筆完成
# 2016 年 NO2 第 5/52 筆完成
# 2016 年 NO2 第 6/52 筆完成
# 2016 年 NO2 第 7/52 筆完成
# 2016 年 NO2 第 8/52 筆完成
# 2016 年 NO2 第 9/52 筆完成
# 2016 年 NO2 第 10/52 筆完成
# 2016 年 NO2 第 11/52 筆完成
# 2016 年 NO2 第 12/52 筆完成
# 2016 年 NO2 第 13/52 筆完成
# 2016 年 NO2 第 14/52 筆完成
# 2016 年 NO2 第 15/52 筆完成
# 2016 年 NO2 第 16/52 筆完成
# 2016 年 NO2 第 17/52 筆完成
# 2016 年 NO2 第 18/52 筆完成
# 2016 年 NO2 第 19/52 筆完成
# 2016 年 NO2 第 20/52 筆完成
# 2016 年 NO2 第 21/52 筆完成
# 2016 年 NO2 第 22/52 筆完成
# 2016 年 NO2 第 23/52 筆完成
# 2016 年 NO2 第 24/52 筆完成
# 2016 年 NO2 第 25/52 筆完成
# 2016 年 NO2 第 26/52 筆完成
# 2016 年 NO2 第 27/52 筆完成
# 2016 年 NO2 第 28/52 筆完成
# 2016 年 NO2 第 29/52 筆完成
# 2016 年 NO2 第 30/52 筆完成
# 2016 年 NO2 第 31/52 筆完成
# 2016 年 NO2 第 32/52 筆完成
# 2016 年 NO2 第 33/52 筆完成
# 2016 年 NO2 第 34/52 筆完成
# 2016 年 NO2 第 35/52 筆完成
# 2016 年 NO2 第 36/52 筆完成
# 2016 年 NO2 第 37/52 筆完成
# 2016 年 NO2 第 38/52 筆完成
# 2016 年 NO2 第 39/52 筆完成
# 2016 年 NO2 第 40/52 筆完成
# 2016 年 NO2 第 41/52 筆完成
# 2016 年 NO2 第 42/52 筆完成
# 2016 年 NO2 第 43/52 筆完成
# 2016 年 NO2 第 44/52 筆完成
# 2016 年 NO2 第 45/52 筆完成
# 2016 年 NO2 第 46/52 筆完成
# 2016 年 NO2 第 47/52 筆完成
# 2016 年 NO2 第 48/52 筆完成
# 2016 年 NO2 第 49/52 筆完成
# 2016 年 NO2 第 50/52 筆完成
# 2016 年 NO2 第 51/52 筆完成
# 2016 年 NO2 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_1.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_2.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_3.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_4.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_5.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_6.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_7.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_8.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_9.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_10.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_11.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_12.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_13.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_14.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_15.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_16.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_17.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_18.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_19.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_20.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_21.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_22.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_23.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_24.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_25.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_26.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_27.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_28.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_29.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_30.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_31.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_32.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_33.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_34.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_35.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_36.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_37.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_38.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_39.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_40.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_41.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_42.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_43.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_44.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_45.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_46.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_47.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_48.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_49.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_50.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_51.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2016_week_52.csv
# 📂 處理 NO2 - 2017，共 52 筆日期
# 2017 年 NO2 第 1/52 筆完成
# 2017 年 NO2 第 2/52 筆完成
# 2017 年 NO2 第 3/52 筆完成
# 2017 年 NO2 第 4/52 筆完成
# 2017 年 NO2 第 5/52 筆完成
# 2017 年 NO2 第 6/52 筆完成
# 2017 年 NO2 第 7/52 筆完成
# 2017 年 NO2 第 8/52 筆完成
# 2017 年 NO2 第 9/52 筆完成
# 2017 年 NO2 第 10/52 筆完成
# 2017 年 NO2 第 11/52 筆完成
# 2017 年 NO2 第 12/52 筆完成
# 2017 年 NO2 第 13/52 筆完成
# 2017 年 NO2 第 14/52 筆完成
# 2017 年 NO2 第 15/52 筆完成
# 2017 年 NO2 第 16/52 筆完成
# 2017 年 NO2 第 17/52 筆完成
# 2017 年 NO2 第 18/52 筆完成
# 2017 年 NO2 第 19/52 筆完成
# 2017 年 NO2 第 20/52 筆完成
# 2017 年 NO2 第 21/52 筆完成
# 2017 年 NO2 第 22/52 筆完成
# 2017 年 NO2 第 23/52 筆完成
# 2017 年 NO2 第 24/52 筆完成
# 2017 年 NO2 第 25/52 筆完成
# 2017 年 NO2 第 26/52 筆完成
# 2017 年 NO2 第 27/52 筆完成
# 2017 年 NO2 第 28/52 筆完成
# 2017 年 NO2 第 29/52 筆完成
# 2017 年 NO2 第 30/52 筆完成
# 2017 年 NO2 第 31/52 筆完成
# 2017 年 NO2 第 32/52 筆完成
# 2017 年 NO2 第 33/52 筆完成
# 2017 年 NO2 第 34/52 筆完成
# 2017 年 NO2 第 35/52 筆完成
# 2017 年 NO2 第 36/52 筆完成
# 2017 年 NO2 第 37/52 筆完成
# 2017 年 NO2 第 38/52 筆完成
# 2017 年 NO2 第 39/52 筆完成
# 2017 年 NO2 第 40/52 筆完成
# 2017 年 NO2 第 41/52 筆完成
# 2017 年 NO2 第 42/52 筆完成
# 2017 年 NO2 第 43/52 筆完成
# 2017 年 NO2 第 44/52 筆完成
# 2017 年 NO2 第 45/52 筆完成
# 2017 年 NO2 第 46/52 筆完成
# 2017 年 NO2 第 47/52 筆完成
# 2017 年 NO2 第 48/52 筆完成
# 2017 年 NO2 第 49/52 筆完成
# 2017 年 NO2 第 50/52 筆完成
# 2017 年 NO2 第 51/52 筆完成
# 2017 年 NO2 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_1.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_2.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_3.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_4.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_5.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_6.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_7.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_8.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_9.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_10.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_11.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_12.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_13.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_14.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_15.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_16.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_17.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_18.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_19.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_20.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_21.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_22.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_23.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_24.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_25.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_26.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_27.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_28.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_29.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_30.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_31.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_32.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_33.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_34.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_35.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_36.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_37.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_38.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_39.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_40.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_41.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_42.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_43.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_44.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_45.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_46.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_47.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_48.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_49.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_50.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_51.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2017_week_52.csv
# 📂 處理 NO2 - 2018，共 52 筆日期
# 2018 年 NO2 第 1/52 筆完成
# 2018 年 NO2 第 2/52 筆完成
# 2018 年 NO2 第 3/52 筆完成
# 2018 年 NO2 第 4/52 筆完成
# 2018 年 NO2 第 5/52 筆完成
# 2018 年 NO2 第 6/52 筆完成
# 2018 年 NO2 第 7/52 筆完成
# 2018 年 NO2 第 8/52 筆完成
# 2018 年 NO2 第 9/52 筆完成
# 2018 年 NO2 第 10/52 筆完成
# 2018 年 NO2 第 11/52 筆完成
# 2018 年 NO2 第 12/52 筆完成
# 2018 年 NO2 第 13/52 筆完成
# 2018 年 NO2 第 14/52 筆完成
# 2018 年 NO2 第 15/52 筆完成
# 2018 年 NO2 第 16/52 筆完成
# 2018 年 NO2 第 17/52 筆完成
# 2018 年 NO2 第 18/52 筆完成
# 2018 年 NO2 第 19/52 筆完成
# 2018 年 NO2 第 20/52 筆完成
# 2018 年 NO2 第 21/52 筆完成
# 2018 年 NO2 第 22/52 筆完成
# 2018 年 NO2 第 23/52 筆完成
# 2018 年 NO2 第 24/52 筆完成
# 2018 年 NO2 第 25/52 筆完成
# 2018 年 NO2 第 26/52 筆完成
# 2018 年 NO2 第 27/52 筆完成
# 2018 年 NO2 第 28/52 筆完成
# 2018 年 NO2 第 29/52 筆完成
# 2018 年 NO2 第 30/52 筆完成
# 2018 年 NO2 第 31/52 筆完成
# 2018 年 NO2 第 32/52 筆完成
# 2018 年 NO2 第 33/52 筆完成
# 2018 年 NO2 第 34/52 筆完成
# 2018 年 NO2 第 35/52 筆完成
# 2018 年 NO2 第 36/52 筆完成
# 2018 年 NO2 第 37/52 筆完成
# 2018 年 NO2 第 38/52 筆完成
# 2018 年 NO2 第 39/52 筆完成
# 2018 年 NO2 第 40/52 筆完成
# 2018 年 NO2 第 41/52 筆完成
# 2018 年 NO2 第 42/52 筆完成
# 2018 年 NO2 第 43/52 筆完成
# 2018 年 NO2 第 44/52 筆完成
# 2018 年 NO2 第 45/52 筆完成
# 2018 年 NO2 第 46/52 筆完成
# 2018 年 NO2 第 47/52 筆完成
# 2018 年 NO2 第 48/52 筆完成
# 2018 年 NO2 第 49/52 筆完成
# 2018 年 NO2 第 50/52 筆完成
# 2018 年 NO2 第 51/52 筆完成
# 2018 年 NO2 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_1.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_2.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_3.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_4.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_5.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_6.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_7.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_8.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_9.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_10.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_11.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_12.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_13.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_14.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_15.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_16.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_17.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_18.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_19.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_20.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_21.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_22.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_23.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_24.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_25.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_26.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_27.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_28.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_29.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_30.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_31.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_32.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_33.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_34.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_35.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_36.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_37.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_38.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_39.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_40.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_41.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_42.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_43.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_44.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_45.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_46.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_47.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_48.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_49.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_50.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_51.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2018_week_52.csv
# 📂 處理 NO2 - 2019，共 52 筆日期
# 2019 年 NO2 第 1/52 筆完成
# 2019 年 NO2 第 2/52 筆完成
# 2019 年 NO2 第 3/52 筆完成
# 2019 年 NO2 第 4/52 筆完成
# 2019 年 NO2 第 5/52 筆完成
# 2019 年 NO2 第 6/52 筆完成
# 2019 年 NO2 第 7/52 筆完成
# 2019 年 NO2 第 8/52 筆完成
# 2019 年 NO2 第 9/52 筆完成
# 2019 年 NO2 第 10/52 筆完成
# 2019 年 NO2 第 11/52 筆完成
# 2019 年 NO2 第 12/52 筆完成
# 2019 年 NO2 第 13/52 筆完成
# 2019 年 NO2 第 14/52 筆完成
# 2019 年 NO2 第 15/52 筆完成
# 2019 年 NO2 第 16/52 筆完成
# 2019 年 NO2 第 17/52 筆完成
# 2019 年 NO2 第 18/52 筆完成
# 2019 年 NO2 第 19/52 筆完成
# 2019 年 NO2 第 20/52 筆完成
# 2019 年 NO2 第 21/52 筆完成
# 2019 年 NO2 第 22/52 筆完成
# 2019 年 NO2 第 23/52 筆完成
# 2019 年 NO2 第 24/52 筆完成
# 2019 年 NO2 第 25/52 筆完成
# 2019 年 NO2 第 26/52 筆完成
# 2019 年 NO2 第 27/52 筆完成
# 2019 年 NO2 第 28/52 筆完成
# 2019 年 NO2 第 29/52 筆完成
# 2019 年 NO2 第 30/52 筆完成
# 2019 年 NO2 第 31/52 筆完成
# 2019 年 NO2 第 32/52 筆完成
# 2019 年 NO2 第 33/52 筆完成
# 2019 年 NO2 第 34/52 筆完成
# 2019 年 NO2 第 35/52 筆完成
# 2019 年 NO2 第 36/52 筆完成
# 2019 年 NO2 第 37/52 筆完成
# 2019 年 NO2 第 38/52 筆完成
# 2019 年 NO2 第 39/52 筆完成
# 2019 年 NO2 第 40/52 筆完成
# 2019 年 NO2 第 41/52 筆完成
# 2019 年 NO2 第 42/52 筆完成
# 2019 年 NO2 第 43/52 筆完成
# 2019 年 NO2 第 44/52 筆完成
# 2019 年 NO2 第 45/52 筆完成
# 2019 年 NO2 第 46/52 筆完成
# 2019 年 NO2 第 47/52 筆完成
# 2019 年 NO2 第 48/52 筆完成
# 2019 年 NO2 第 49/52 筆完成
# 2019 年 NO2 第 50/52 筆完成
# 2019 年 NO2 第 51/52 筆完成
# 2019 年 NO2 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_1.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_2.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_3.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_4.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_5.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_6.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_7.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_8.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_9.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_10.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_11.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_12.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_13.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_14.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_15.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_16.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_17.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_18.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_19.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_20.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_21.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_22.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_23.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_24.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_25.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_26.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_27.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_28.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_29.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_30.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_31.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_32.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_33.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_34.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_35.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_36.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_37.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_38.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_39.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_40.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_41.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_42.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_43.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_44.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_45.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_46.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_47.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_48.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_49.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_50.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_51.csv
# ✅ 輸出：./5_grid_output/NO2/NO2_2019_week_52.csv
# 📂 處理 NOx - 2015，共 52 筆日期
# 2015 年 NOx 第 1/52 筆完成
# 2015 年 NOx 第 2/52 筆完成
# 2015 年 NOx 第 3/52 筆完成
# 2015 年 NOx 第 4/52 筆完成
# 2015 年 NOx 第 5/52 筆完成
# 2015 年 NOx 第 6/52 筆完成
# 2015 年 NOx 第 7/52 筆完成
# 2015 年 NOx 第 8/52 筆完成
# 2015 年 NOx 第 9/52 筆完成
# 2015 年 NOx 第 10/52 筆完成
# 2015 年 NOx 第 11/52 筆完成
# 2015 年 NOx 第 12/52 筆完成
# 2015 年 NOx 第 13/52 筆完成
# 2015 年 NOx 第 14/52 筆完成
# 2015 年 NOx 第 15/52 筆完成
# 2015 年 NOx 第 16/52 筆完成
# 2015 年 NOx 第 17/52 筆完成
# 2015 年 NOx 第 18/52 筆完成
# 2015 年 NOx 第 19/52 筆完成
# 2015 年 NOx 第 20/52 筆完成
# 2015 年 NOx 第 21/52 筆完成
# 2015 年 NOx 第 22/52 筆完成
# 2015 年 NOx 第 23/52 筆完成
# 2015 年 NOx 第 24/52 筆完成
# 2015 年 NOx 第 25/52 筆完成
# 2015 年 NOx 第 26/52 筆完成
# 2015 年 NOx 第 27/52 筆完成
# 2015 年 NOx 第 28/52 筆完成
# 2015 年 NOx 第 29/52 筆完成
# 2015 年 NOx 第 30/52 筆完成
# 2015 年 NOx 第 31/52 筆完成
# 2015 年 NOx 第 32/52 筆完成
# 2015 年 NOx 第 33/52 筆完成
# 2015 年 NOx 第 34/52 筆完成
# 2015 年 NOx 第 35/52 筆完成
# 2015 年 NOx 第 36/52 筆完成
# 2015 年 NOx 第 37/52 筆完成
# 2015 年 NOx 第 38/52 筆完成
# 2015 年 NOx 第 39/52 筆完成
# 2015 年 NOx 第 40/52 筆完成
# 2015 年 NOx 第 41/52 筆完成
# 2015 年 NOx 第 42/52 筆完成
# 2015 年 NOx 第 43/52 筆完成
# 2015 年 NOx 第 44/52 筆完成
# 2015 年 NOx 第 45/52 筆完成
# 2015 年 NOx 第 46/52 筆完成
# 2015 年 NOx 第 47/52 筆完成
# 2015 年 NOx 第 48/52 筆完成
# 2015 年 NOx 第 49/52 筆完成
# 2015 年 NOx 第 50/52 筆完成
# 2015 年 NOx 第 51/52 筆完成
# 2015 年 NOx 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_1.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_2.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_3.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_4.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_5.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_6.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_7.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_8.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_9.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_10.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_11.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_12.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_13.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_14.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_15.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_16.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_17.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_18.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_19.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_20.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_21.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_22.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_23.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_24.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_25.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_26.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_27.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_28.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_29.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_30.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_31.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_32.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_33.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_34.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_35.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_36.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_37.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_38.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_39.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_40.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_41.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_42.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_43.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_44.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_45.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_46.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_47.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_48.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_49.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_50.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_51.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2015_week_52.csv
# 📂 處理 NOx - 2016，共 52 筆日期
# 2016 年 NOx 第 1/52 筆完成
# 2016 年 NOx 第 2/52 筆完成
# 2016 年 NOx 第 3/52 筆完成
# 2016 年 NOx 第 4/52 筆完成
# 2016 年 NOx 第 5/52 筆完成
# 2016 年 NOx 第 6/52 筆完成
# 2016 年 NOx 第 7/52 筆完成
# 2016 年 NOx 第 8/52 筆完成
# 2016 年 NOx 第 9/52 筆完成
# 2016 年 NOx 第 10/52 筆完成
# 2016 年 NOx 第 11/52 筆完成
# 2016 年 NOx 第 12/52 筆完成
# 2016 年 NOx 第 13/52 筆完成
# 2016 年 NOx 第 14/52 筆完成
# 2016 年 NOx 第 15/52 筆完成
# 2016 年 NOx 第 16/52 筆完成
# 2016 年 NOx 第 17/52 筆完成
# 2016 年 NOx 第 18/52 筆完成
# 2016 年 NOx 第 19/52 筆完成
# 2016 年 NOx 第 20/52 筆完成
# 2016 年 NOx 第 21/52 筆完成
# 2016 年 NOx 第 22/52 筆完成
# 2016 年 NOx 第 23/52 筆完成
# 2016 年 NOx 第 24/52 筆完成
# 2016 年 NOx 第 25/52 筆完成
# 2016 年 NOx 第 26/52 筆完成
# 2016 年 NOx 第 27/52 筆完成
# 2016 年 NOx 第 28/52 筆完成
# 2016 年 NOx 第 29/52 筆完成
# 2016 年 NOx 第 30/52 筆完成
# 2016 年 NOx 第 31/52 筆完成
# 2016 年 NOx 第 32/52 筆完成
# 2016 年 NOx 第 33/52 筆完成
# 2016 年 NOx 第 34/52 筆完成
# 2016 年 NOx 第 35/52 筆完成
# 2016 年 NOx 第 36/52 筆完成
# 2016 年 NOx 第 37/52 筆完成
# 2016 年 NOx 第 38/52 筆完成
# 2016 年 NOx 第 39/52 筆完成
# 2016 年 NOx 第 40/52 筆完成
# 2016 年 NOx 第 41/52 筆完成
# 2016 年 NOx 第 42/52 筆完成
# 2016 年 NOx 第 43/52 筆完成
# 2016 年 NOx 第 44/52 筆完成
# 2016 年 NOx 第 45/52 筆完成
# 2016 年 NOx 第 46/52 筆完成
# 2016 年 NOx 第 47/52 筆完成
# 2016 年 NOx 第 48/52 筆完成
# 2016 年 NOx 第 49/52 筆完成
# 2016 年 NOx 第 50/52 筆完成
# 2016 年 NOx 第 51/52 筆完成
# 2016 年 NOx 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_1.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_2.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_3.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_4.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_5.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_6.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_7.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_8.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_9.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_10.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_11.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_12.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_13.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_14.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_15.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_16.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_17.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_18.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_19.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_20.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_21.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_22.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_23.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_24.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_25.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_26.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_27.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_28.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_29.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_30.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_31.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_32.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_33.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_34.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_35.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_36.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_37.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_38.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_39.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_40.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_41.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_42.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_43.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_44.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_45.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_46.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_47.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_48.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_49.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_50.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_51.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2016_week_52.csv
# 📂 處理 NOx - 2017，共 52 筆日期
# 2017 年 NOx 第 1/52 筆完成
# 2017 年 NOx 第 2/52 筆完成
# 2017 年 NOx 第 3/52 筆完成
# 2017 年 NOx 第 4/52 筆完成
# 2017 年 NOx 第 5/52 筆完成
# 2017 年 NOx 第 6/52 筆完成
# 2017 年 NOx 第 7/52 筆完成
# 2017 年 NOx 第 8/52 筆完成
# 2017 年 NOx 第 9/52 筆完成
# 2017 年 NOx 第 10/52 筆完成
# 2017 年 NOx 第 11/52 筆完成
# 2017 年 NOx 第 12/52 筆完成
# 2017 年 NOx 第 13/52 筆完成
# 2017 年 NOx 第 14/52 筆完成
# 2017 年 NOx 第 15/52 筆完成
# 2017 年 NOx 第 16/52 筆完成
# 2017 年 NOx 第 17/52 筆完成
# 2017 年 NOx 第 18/52 筆完成
# 2017 年 NOx 第 19/52 筆完成
# 2017 年 NOx 第 20/52 筆完成
# 2017 年 NOx 第 21/52 筆完成
# 2017 年 NOx 第 22/52 筆完成
# 2017 年 NOx 第 23/52 筆完成
# 2017 年 NOx 第 24/52 筆完成
# 2017 年 NOx 第 25/52 筆完成
# 2017 年 NOx 第 26/52 筆完成
# 2017 年 NOx 第 27/52 筆完成
# 2017 年 NOx 第 28/52 筆完成
# 2017 年 NOx 第 29/52 筆完成
# 2017 年 NOx 第 30/52 筆完成
# 2017 年 NOx 第 31/52 筆完成
# 2017 年 NOx 第 32/52 筆完成
# 2017 年 NOx 第 33/52 筆完成
# 2017 年 NOx 第 34/52 筆完成
# 2017 年 NOx 第 35/52 筆完成
# 2017 年 NOx 第 36/52 筆完成
# 2017 年 NOx 第 37/52 筆完成
# 2017 年 NOx 第 38/52 筆完成
# 2017 年 NOx 第 39/52 筆完成
# 2017 年 NOx 第 40/52 筆完成
# 2017 年 NOx 第 41/52 筆完成
# 2017 年 NOx 第 42/52 筆完成
# 2017 年 NOx 第 43/52 筆完成
# 2017 年 NOx 第 44/52 筆完成
# 2017 年 NOx 第 45/52 筆完成
# 2017 年 NOx 第 46/52 筆完成
# 2017 年 NOx 第 47/52 筆完成
# 2017 年 NOx 第 48/52 筆完成
# 2017 年 NOx 第 49/52 筆完成
# 2017 年 NOx 第 50/52 筆完成
# 2017 年 NOx 第 51/52 筆完成
# 2017 年 NOx 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_1.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_2.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_3.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_4.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_5.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_6.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_7.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_8.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_9.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_10.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_11.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_12.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_13.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_14.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_15.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_16.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_17.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_18.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_19.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_20.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_21.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_22.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_23.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_24.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_25.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_26.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_27.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_28.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_29.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_30.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_31.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_32.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_33.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_34.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_35.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_36.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_37.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_38.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_39.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_40.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_41.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_42.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_43.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_44.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_45.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_46.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_47.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_48.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_49.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_50.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_51.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2017_week_52.csv
# 📂 處理 NOx - 2018，共 52 筆日期
# 2018 年 NOx 第 1/52 筆完成
# 2018 年 NOx 第 2/52 筆完成
# 2018 年 NOx 第 3/52 筆完成
# 2018 年 NOx 第 4/52 筆完成
# 2018 年 NOx 第 5/52 筆完成
# 2018 年 NOx 第 6/52 筆完成
# 2018 年 NOx 第 7/52 筆完成
# 2018 年 NOx 第 8/52 筆完成
# 2018 年 NOx 第 9/52 筆完成
# 2018 年 NOx 第 10/52 筆完成
# 2018 年 NOx 第 11/52 筆完成
# 2018 年 NOx 第 12/52 筆完成
# 2018 年 NOx 第 13/52 筆完成
# 2018 年 NOx 第 14/52 筆完成
# 2018 年 NOx 第 15/52 筆完成
# 2018 年 NOx 第 16/52 筆完成
# 2018 年 NOx 第 17/52 筆完成
# 2018 年 NOx 第 18/52 筆完成
# 2018 年 NOx 第 19/52 筆完成
# 2018 年 NOx 第 20/52 筆完成
# 2018 年 NOx 第 21/52 筆完成
# 2018 年 NOx 第 22/52 筆完成
# 2018 年 NOx 第 23/52 筆完成
# 2018 年 NOx 第 24/52 筆完成
# 2018 年 NOx 第 25/52 筆完成
# 2018 年 NOx 第 26/52 筆完成
# 2018 年 NOx 第 27/52 筆完成
# 2018 年 NOx 第 28/52 筆完成
# 2018 年 NOx 第 29/52 筆完成
# 2018 年 NOx 第 30/52 筆完成
# 2018 年 NOx 第 31/52 筆完成
# 2018 年 NOx 第 32/52 筆完成
# 2018 年 NOx 第 33/52 筆完成
# 2018 年 NOx 第 34/52 筆完成
# 2018 年 NOx 第 35/52 筆完成
# 2018 年 NOx 第 36/52 筆完成
# 2018 年 NOx 第 37/52 筆完成
# 2018 年 NOx 第 38/52 筆完成
# 2018 年 NOx 第 39/52 筆完成
# 2018 年 NOx 第 40/52 筆完成
# 2018 年 NOx 第 41/52 筆完成
# 2018 年 NOx 第 42/52 筆完成
# 2018 年 NOx 第 43/52 筆完成
# 2018 年 NOx 第 44/52 筆完成
# 2018 年 NOx 第 45/52 筆完成
# 2018 年 NOx 第 46/52 筆完成
# 2018 年 NOx 第 47/52 筆完成
# 2018 年 NOx 第 48/52 筆完成
# 2018 年 NOx 第 49/52 筆完成
# 2018 年 NOx 第 50/52 筆完成
# 2018 年 NOx 第 51/52 筆完成
# 2018 年 NOx 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_1.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_2.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_3.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_4.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_5.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_6.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_7.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_8.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_9.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_10.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_11.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_12.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_13.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_14.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_15.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_16.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_17.csv
# ✅ 輸出：./5_grid_output/NOx/NOx_2018_week_18.csv
# ...
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_40.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_41.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_42.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_43.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_44.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_45.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_46.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_47.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_48.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_49.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_50.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_51.csv
# ✅ 輸出：./5_grid_output/PM10/PM10_2019_week_52.csv
# 📂 處理 PM25 - 2015，共 52 筆日期
# 2015 年 PM25 第 1/52 筆完成
# 2015 年 PM25 第 2/52 筆完成
# 2015 年 PM25 第 3/52 筆完成
# 2015 年 PM25 第 4/52 筆完成
# 2015 年 PM25 第 5/52 筆完成
# 2015 年 PM25 第 6/52 筆完成
# 2015 年 PM25 第 7/52 筆完成
# 2015 年 PM25 第 8/52 筆完成
# 2015 年 PM25 第 9/52 筆完成
# 2015 年 PM25 第 10/52 筆完成
# 2015 年 PM25 第 11/52 筆完成
# 2015 年 PM25 第 12/52 筆完成
# 2015 年 PM25 第 13/52 筆完成
# 2015 年 PM25 第 14/52 筆完成
# 2015 年 PM25 第 15/52 筆完成
# 2015 年 PM25 第 16/52 筆完成
# 2015 年 PM25 第 17/52 筆完成
# 2015 年 PM25 第 18/52 筆完成
# 2015 年 PM25 第 19/52 筆完成
# 2015 年 PM25 第 20/52 筆完成
# 2015 年 PM25 第 21/52 筆完成
# 2015 年 PM25 第 22/52 筆完成
# 2015 年 PM25 第 23/52 筆完成
# 2015 年 PM25 第 24/52 筆完成
# 2015 年 PM25 第 25/52 筆完成
# 2015 年 PM25 第 26/52 筆完成
# 2015 年 PM25 第 27/52 筆完成
# 2015 年 PM25 第 28/52 筆完成
# 2015 年 PM25 第 29/52 筆完成
# 2015 年 PM25 第 30/52 筆完成
# 2015 年 PM25 第 31/52 筆完成
# 2015 年 PM25 第 32/52 筆完成
# 2015 年 PM25 第 33/52 筆完成
# 2015 年 PM25 第 34/52 筆完成
# 2015 年 PM25 第 35/52 筆完成
# 2015 年 PM25 第 36/52 筆完成
# 2015 年 PM25 第 37/52 筆完成
# 2015 年 PM25 第 38/52 筆完成
# 2015 年 PM25 第 39/52 筆完成
# 2015 年 PM25 第 40/52 筆完成
# 2015 年 PM25 第 41/52 筆完成
# 2015 年 PM25 第 42/52 筆完成
# 2015 年 PM25 第 43/52 筆完成
# 2015 年 PM25 第 44/52 筆完成
# 2015 年 PM25 第 45/52 筆完成
# 2015 年 PM25 第 46/52 筆完成
# 2015 年 PM25 第 47/52 筆完成
# 2015 年 PM25 第 48/52 筆完成
# 2015 年 PM25 第 49/52 筆完成
# 2015 年 PM25 第 50/52 筆完成
# 2015 年 PM25 第 51/52 筆完成
# 2015 年 PM25 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_1.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_2.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_3.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_4.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_5.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_6.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_7.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_8.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_9.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_10.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_11.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_12.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_13.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_14.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_15.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_16.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_17.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_18.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_19.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_20.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_21.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_22.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_23.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_24.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_25.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_26.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_27.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_28.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_29.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_30.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_31.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_32.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_33.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_34.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_35.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_36.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_37.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_38.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_39.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_40.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_41.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_42.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_43.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_44.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_45.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_46.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_47.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_48.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_49.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_50.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_51.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2015_week_52.csv
# 📂 處理 PM25 - 2016，共 52 筆日期
# 2016 年 PM25 第 1/52 筆完成
# 2016 年 PM25 第 2/52 筆完成
# 2016 年 PM25 第 3/52 筆完成
# 2016 年 PM25 第 4/52 筆完成
# 2016 年 PM25 第 5/52 筆完成
# 2016 年 PM25 第 6/52 筆完成
# 2016 年 PM25 第 7/52 筆完成
# 2016 年 PM25 第 8/52 筆完成
# 2016 年 PM25 第 9/52 筆完成
# 2016 年 PM25 第 10/52 筆完成
# 2016 年 PM25 第 11/52 筆完成
# 2016 年 PM25 第 12/52 筆完成
# 2016 年 PM25 第 13/52 筆完成
# 2016 年 PM25 第 14/52 筆完成
# 2016 年 PM25 第 15/52 筆完成
# 2016 年 PM25 第 16/52 筆完成
# 2016 年 PM25 第 17/52 筆完成
# 2016 年 PM25 第 18/52 筆完成
# 2016 年 PM25 第 19/52 筆完成
# 2016 年 PM25 第 20/52 筆完成
# 2016 年 PM25 第 21/52 筆完成
# 2016 年 PM25 第 22/52 筆完成
# 2016 年 PM25 第 23/52 筆完成
# 2016 年 PM25 第 24/52 筆完成
# 2016 年 PM25 第 25/52 筆完成
# 2016 年 PM25 第 26/52 筆完成
# 2016 年 PM25 第 27/52 筆完成
# 2016 年 PM25 第 28/52 筆完成
# 2016 年 PM25 第 29/52 筆完成
# 2016 年 PM25 第 30/52 筆完成
# 2016 年 PM25 第 31/52 筆完成
# 2016 年 PM25 第 32/52 筆完成
# 2016 年 PM25 第 33/52 筆完成
# 2016 年 PM25 第 34/52 筆完成
# 2016 年 PM25 第 35/52 筆完成
# 2016 年 PM25 第 36/52 筆完成
# 2016 年 PM25 第 37/52 筆完成
# 2016 年 PM25 第 38/52 筆完成
# 2016 年 PM25 第 39/52 筆完成
# 2016 年 PM25 第 40/52 筆完成
# 2016 年 PM25 第 41/52 筆完成
# 2016 年 PM25 第 42/52 筆完成
# 2016 年 PM25 第 43/52 筆完成
# 2016 年 PM25 第 44/52 筆完成
# 2016 年 PM25 第 45/52 筆完成
# 2016 年 PM25 第 46/52 筆完成
# 2016 年 PM25 第 47/52 筆完成
# 2016 年 PM25 第 48/52 筆完成
# 2016 年 PM25 第 49/52 筆完成
# 2016 年 PM25 第 50/52 筆完成
# 2016 年 PM25 第 51/52 筆完成
# 2016 年 PM25 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_1.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_2.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_3.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_4.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_5.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_6.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_7.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_8.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_9.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_10.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_11.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_12.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_13.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_14.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_15.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_16.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_17.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_18.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_19.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_20.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_21.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_22.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_23.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_24.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_25.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_26.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_27.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_28.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_29.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_30.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_31.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_32.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_33.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_34.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_35.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_36.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_37.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_38.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_39.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_40.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_41.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_42.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_43.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_44.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_45.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_46.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_47.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_48.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_49.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_50.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_51.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2016_week_52.csv
# 📂 處理 PM25 - 2017，共 52 筆日期
# 2017 年 PM25 第 1/52 筆完成
# 2017 年 PM25 第 2/52 筆完成
# 2017 年 PM25 第 3/52 筆完成
# 2017 年 PM25 第 4/52 筆完成
# 2017 年 PM25 第 5/52 筆完成
# 2017 年 PM25 第 6/52 筆完成
# 2017 年 PM25 第 7/52 筆完成
# 2017 年 PM25 第 8/52 筆完成
# 2017 年 PM25 第 9/52 筆完成
# 2017 年 PM25 第 10/52 筆完成
# 2017 年 PM25 第 11/52 筆完成
# 2017 年 PM25 第 12/52 筆完成
# 2017 年 PM25 第 13/52 筆完成
# 2017 年 PM25 第 14/52 筆完成
# 2017 年 PM25 第 15/52 筆完成
# 2017 年 PM25 第 16/52 筆完成
# 2017 年 PM25 第 17/52 筆完成
# 2017 年 PM25 第 18/52 筆完成
# 2017 年 PM25 第 19/52 筆完成
# 2017 年 PM25 第 20/52 筆完成
# 2017 年 PM25 第 21/52 筆完成
# 2017 年 PM25 第 22/52 筆完成
# 2017 年 PM25 第 23/52 筆完成
# 2017 年 PM25 第 24/52 筆完成
# 2017 年 PM25 第 25/52 筆完成
# 2017 年 PM25 第 26/52 筆完成
# 2017 年 PM25 第 27/52 筆完成
# 2017 年 PM25 第 28/52 筆完成
# 2017 年 PM25 第 29/52 筆完成
# 2017 年 PM25 第 30/52 筆完成
# 2017 年 PM25 第 31/52 筆完成
# 2017 年 PM25 第 32/52 筆完成
# 2017 年 PM25 第 33/52 筆完成
# 2017 年 PM25 第 34/52 筆完成
# 2017 年 PM25 第 35/52 筆完成
# 2017 年 PM25 第 36/52 筆完成
# 2017 年 PM25 第 37/52 筆完成
# 2017 年 PM25 第 38/52 筆完成
# 2017 年 PM25 第 39/52 筆完成
# 2017 年 PM25 第 40/52 筆完成
# 2017 年 PM25 第 41/52 筆完成
# 2017 年 PM25 第 42/52 筆完成
# 2017 年 PM25 第 43/52 筆完成
# 2017 年 PM25 第 44/52 筆完成
# 2017 年 PM25 第 45/52 筆完成
# 2017 年 PM25 第 46/52 筆完成
# 2017 年 PM25 第 47/52 筆完成
# 2017 年 PM25 第 48/52 筆完成
# 2017 年 PM25 第 49/52 筆完成
# 2017 年 PM25 第 50/52 筆完成
# 2017 年 PM25 第 51/52 筆完成
# 2017 年 PM25 第 52/52 筆完成
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_1.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_2.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_3.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_4.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_5.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_6.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_7.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_8.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_9.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_10.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_11.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_12.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_13.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_14.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_15.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_16.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_17.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_18.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_19.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_20.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_21.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_22.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_23.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_24.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_25.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_26.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_27.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_28.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_29.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_30.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_31.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_32.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_33.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_34.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_35.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_36.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_37.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_38.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_39.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_40.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_41.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_42.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_43.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_44.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_45.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_46.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_47.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_48.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_49.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_50.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_51.csv
# ✅ 輸出：./5_grid_output/PM25/PM25_2017_week_52.csv
# 📂 處理 PM25 - 2018，共 52 筆日期
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 60
#      56     output_base = './5_grid_output'
#      57
#      58     for factor in factors:
#      59         factor_folder = os.path.join(output_base, factor.replace('.', ''))  # PM2.5 → PM25
# ---> 60         interpolate_by_idw(factor.replace('.', ''), input_dir, factor_folder)
#
# Cell In[5], line 40, in interpolate_by_idw(factor, input_dir, output_dir)
#      36                 print(f"⚠️ {date_str} 無任何資料，跳過")
#      37                 m2.append(np.full((120, 120), np.nan))
#      38                 continue
#      39
# ---> 40             grid = calculate_idw(df_merge)
#      41             m2.append(grid)
#      42             print(f"{year} 年 {factor} 第 {count+1}/{len(df)} 筆完成")
#      43
#
# Cell In[4], line 27, in calculate_idw(data)
#      23         nested = []
#      24         for i in np.arange(119, 122.7, iInterval):
#      25             point = {'x': i, 'y': j}
#      26             if helper.is_in_area(index1, index2):
# ---> 27                 nested.append(calc_idw_value(point, df))
#      28             else:
#      29                 nested.append(-1)
#      30             index2 += 1
#
# Cell In[3], line 5, in calc_idw_value(unknowncell, knowncells)
#       1 def calc_idw_value(unknowncell, knowncells):
#       2     sumwei = 0.0
#       3     sumpm = 0.0
#       4     wei = 0.0
# ----> 5     for index, row in knowncells.iterrows():
#       6         px = unknowncell['x']
#       7         py = unknowncell['y']
#       8         pm = row['value']
#
# File /workspaces/CHCS_IDW_to_ratio/.venv/lib/python3.12/site-packages/pandas/core/frame.py:1586, in DataFrame.iterrows(self)
#    1582         """
#    1583         columns = self.columns
#    1584         klass = self._constructor_sliced
#    1585         for k, v in zip(self.index, self.values, strict=True):
# -> 1586             s = klass(v, index=columns, name=k).__finalize__(self)
#    1587             if self._mgr.is_single_block:
#    1588                 s._mgr.add_references(self._mgr)
#    1589             yield k, s
#
# File /workspaces/CHCS_IDW_to_ratio/.venv/lib/python3.12/site-packages/pandas/core/series.py:514, in Series.__init__(self, data, index, dtype, name, copy)
#     512         data = data.copy(deep=True)
#     513 else:
# --> 514     data = sanitize_array(data, index, dtype, copy)
#     515     data = SingleBlockManager.from_array(data, index, refs=refs)
#     517 NDFrame.__init__(self, data)
#
# File /workspaces/CHCS_IDW_to_ratio/.venv/lib/python3.12/site-packages/pandas/core/construction.py:616, in sanitize_array(data, index, dtype, copy, allow_2d)
#     614 subarr = data
#     615 if data.dtype == object and infer_object:
# --> 616     subarr = lib.maybe_convert_objects(
#     617         data,
#     618         # Here we do not convert numeric dtypes, as if we wanted that,
#     619         #  numpy would have done it for us.
#     620         convert_numeric=False,
#     621         convert_non_numeric=True,
#     622         convert_to_nullable_dtype=False,
#     623         dtype_if_all_nat=np.dtype("M8[s]"),
#     624     )
#     625 elif data.dtype.kind == "U" and using_string_dtype():
#     626     from pandas.core.arrays.string_ import StringDtype
#
# File pandas/_libs/lib.pyx:2634, in pandas._libs.lib.maybe_convert_objects()
# -> 2634 'Could not get source, probably due dynamically evaluated source code.'
#
# File /workspaces/CHCS_IDW_to_ratio/.venv/lib/python3.12/site-packages/numpy/_core/numeric.py:323, in full(shape, fill_value, dtype, order, device, like)
#     317 def _full_dispatcher(
#     318     shape, fill_value, dtype=None, order=None, *, device=None, like=None
#     319 ):
#     320     return (like,)
# --> 323 @finalize_array_function_like
#     324 @set_module('numpy')
#     325 def full(shape, fill_value, dtype=None, order='C', *, device=None, like=None):
#     326     """
#     327     Return a new array of given shape and type, filled with `fill_value`.
#     328
#    (...)    375
#     376     """
#     377     if like is not None:
#
# KeyboardInterrupt:
